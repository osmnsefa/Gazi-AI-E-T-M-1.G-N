# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
# Out:
# C:\Users\Asus\anaconda3\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\Asus\anaconda3\lib\site-packages\numpy\.libs\libopenblas.FB5AE2TYXYH2IJRDKGDGQ3XBKLKTF43H.gfortran-win_amd64.dll
# C:\Users\Asus\anaconda3\lib\site-packages\numpy\.libs\libopenblas64__v0.3.21-gcc_10_3_0.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
img = cv2.imread("london.jpg",0)
plt.figure(), plt.imshow(img, cmap = "gray"), plt.axis("off")
# Out:
# (<Figure size 640x480 with 1 Axes>,
#  <matplotlib.image.AxesImage at 0x277816e0550>,
#  (-0.5, 1199.5, 1199.5, -0.5))

# %%
edges = cv2.Canny(image = img, threshold1 = 0, threshold2 = 255) 
plt.figure(), plt.imshow(edges, cmap = "gray"), plt.axis("off")
# Out:
# (<Figure size 640x480 with 1 Axes>,
#  <matplotlib.image.AxesImage at 0x20b3e888070>,
#  (-0.5, 1199.5, 1199.5, -0.5))

# %%
med_val = np.median(img) 
print(med_val)
# Out:
# 140.0

# %%
# threshold belirlemek için kullanılan formüller
low = int(max(0, (1 - 0.33)* med_val)) 
high = int(min(255, (1 + 0.33)* med_val))
print(low)
print(high)
# Out:
# 93
# 186

# %%
edges = cv2.Canny(image = img, threshold1 = low, threshold2 = high) 
plt.figure(), plt.imshow(edges, cmap = "gray"), plt.axis("off")
# Out:
# (<Figure size 640x480 with 1 Axes>,
#  <matplotlib.image.AxesImage at 0x20b3e309fa0>,
#  (-0.5, 1199.5, 1199.5, -0.5))

# %%
#blur
blurred_img = cv2.blur(img, ksize = (5,5)) # kernel size değiştirmenin fazlasıyla etkisi var
plt.figure(), plt.imshow(blurred_img, cmap = "gray"), plt.axis("off")
# Out:
# (<Figure size 640x480 with 1 Axes>,
#  <matplotlib.image.AxesImage at 0x27781ac0df0>,
#  (-0.5, 1199.5, 1199.5, -0.5))

# %%
med_val = np.median(blurred_img) #threshold belirlemek için (blurlu hali)
print(med_val)
# Out:
# 139.0

# %%
# threshold belirlemek için kullanılan formüller
low = int(max(0, (1 - 0.33)* med_val)) 
high = int(min(255, (1 + 0.33)* med_val))
print(low)
print(high)
# Out:
# 93
# 184

# %%
edges = cv2.Canny(image = blurred_img, threshold1 = low, threshold2 = high) 
plt.figure(), plt.imshow(edges, cmap = "gray"), plt.axis("off")
# Out:
# (<Figure size 640x480 with 1 Axes>,
#  <matplotlib.image.AxesImage at 0x27781b0aaf0>,
#  (-0.5, 1199.5, 1199.5, -0.5))

# %%
# Son işlemde resmin detaylarını biraz kaybetmiş olduk ama kenarlarını artık daha iyi tespit ediyoruz.
